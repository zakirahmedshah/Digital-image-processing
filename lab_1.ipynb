# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load the grayscale image
image_path = image_path = 'c:\\Users\\dell\\Downloads\\closeup-grayscale-shot-american-bald-eagle-dark-background.jpg'


# Display the grayscale image
plt.imshow(gray_image, cmap='gray')
plt.axis('off')  # Turn off axis
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 9
#       5 image_path = image_path = 'c:\\Users\\dell\\Downloads\\closeup-grayscale-shot-american-bald-eagle-dark-background.jpg'
#       8 # Display the grayscale image
# ----> 9 plt.imshow(gray_image, cmap='gray')
#      10 plt.axis('off')  # Turn off axis
#      11 plt.show()
#
# NameError: name 'gray_image' is not defined

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load the grayscale image
image_path = r'c:\Users\dell\Downloads\closeup-grayscale-shot-american-bald-eagle-dark-background.jpg'
gray_image = mpimg.imread(image_path)

# Display the grayscale image
plt.imshow(gray_image, cmap='gray')
plt.axis('off')  # Turn off axis
plt.show()
